# %% [markdown]
# <a href="https://colab.research.google.com/github/everestso/47.53.59/blob/master/TitanicTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Test

# %%
import pandas as pd

titanic = pd.read_csv("http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv")
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic[titanic['name'].str.contains('Rev.')]
# Out:
#      pclass  survived  ...   body                       home.dest
# 335       2         0  ...  174.0                Jacksonville, FL
# 357       2         0  ...    NaN                          London
# 366       2         0  ...    NaN                          London
# 431       2         0  ...    NaN  Denmark Hill, Surrey / Chicago
# 472       2         0  ...    NaN            Glasgow / Bangor, ME
# 476       2         0  ...    NaN                 Minneapolis, MN
# 507       2         0  ...    NaN                   Worcester, MA
# 532       2         0  ...    NaN                             NaN
#
# [8 rows x 14 columns]

# %%
from IPython.display import display, HTML
from urllib.request import urlopen

link = "https://en.wikipedia.org/wiki/Thomas_Byles"
f = urlopen(link)
myfile = f.read().decode('utf-8')[:11900]
h = HTML(myfile)
display(h)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Thomas Byles - Wikipedia</title>
# ...

# %%
link = "https://cruxnow.com/johns-journal/2018/08/as-it-turns-out-theres-religious-subtext-to-the-titanic-too/"
f = urlopen(link)
myfile = f.read().decode('utf-8')[:70000]
h = HTML(myfile)
display(h)
# Out:
# <!DOCTYPE html>
# <html lang="en-CA">
# 		<head>
# 		<!--meta-->
# 		<meta charset="UTF-8" />
# 		<meta name="generator" content="WordPress 5.4" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.2" />
# 		<meta property="fb:pages" content="1489943574572290" />
# 		<meta name="format-detection" content="telephone=no" />
# 		<!--style-->
# 		<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="https://cruxnow.com/feed/" />
# 		<link rel="pingback" href="https://cruxnow.com/xmlrpc.php" />
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"zOlon1aMp410O7", domain:"cruxnow.com",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# ...
